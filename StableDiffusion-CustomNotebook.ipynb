# %% [markdown]
# # Stable Diffusion Notebook

# %%
# !nvidia-smi
# Out:
# Wed Aug 24 00:24:54 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A10G         On   | 00000000:00:1E.0 Off |                    0 |
# |  0%   31C    P8    16W / 300W |      0MiB / 23028MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install diffusers==0.2.4
# !pip install transformers scipy ftfy
# !pip install "ipywidgets>=7,<8"
# !pip install huggingface-hub
# !pip install torch
# !pip list
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: diffusers==0.2.4 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (0.2.4)
# Requirement already satisfied: Pillow in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from diffusers==0.2.4) (9.0.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.8.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from diffusers==0.2.4) (0.9.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from diffusers==0.2.4) (2021.11.10)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from diffusers==0.2.4) (4.8.2)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from diffusers==0.2.4) (3.4.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from diffusers==0.2.4) (2.26.0)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from diffusers==0.2.4) (1.21.2)
# Requirement already satisfied: torch>=1.4 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from diffusers==0.2.4) (1.10.0)
# Requirement already satisfied: packaging>=20.9 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.8.1->diffusers==0.2.4) (21.3)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.8.1->diffusers==0.2.4) (4.62.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.8.1->diffusers==0.2.4) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.8.1->diffusers==0.2.4) (4.0.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from importlib-metadata->diffusers==0.2.4) (3.6.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->diffusers==0.2.4) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->diffusers==0.2.4) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->diffusers==0.2.4) (3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->diffusers==0.2.4) (1.26.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from packaging>=20.9->huggingface-hub<1.0,>=0.8.1->diffusers==0.2.4) (3.0.6)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: transformers in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (4.21.1)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (1.7.2)
# Requirement already satisfied: ftfy in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (6.1.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from transformers) (0.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from transformers) (5.4.1)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from transformers) (3.4.0)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from transformers) (2.26.0)
# Requirement already satisfied: tqdm>=4.27 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from transformers) (4.62.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from transformers) (0.12.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from transformers) (2021.11.10)
# Requirement already satisfied: numpy>=1.17 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from transformers) (1.21.2)
# Requirement already satisfied: wcwidth>=0.2.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ftfy) (0.2.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from packaging>=20.0->transformers) (3.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->transformers) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->transformers) (3.1)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: ipywidgets<8,>=7 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (7.6.5)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipywidgets<8,>=7) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipywidgets<8,>=7) (7.32.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipywidgets<8,>=7) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipywidgets<8,>=7) (1.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipywidgets<8,>=7) (6.5.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipywidgets<8,>=7) (3.5.2)
# Requirement already satisfied: nbformat>=4.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipywidgets<8,>=7) (5.1.3)
# Requirement already satisfied: jupyter-client<8.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (7.1.0)
# Requirement already satisfied: tornado<7.0,>=4.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7) (0.1.3)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (3.0.22)
# Requirement already satisfied: backcall in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (0.2.0)
# Requirement already satisfied: pygments in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (2.10.0)
# Requirement already satisfied: pexpect>4.3 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (59.2.0)
# Requirement already satisfied: pickleshare in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (0.7.5)
# Requirement already satisfied: decorator in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from ipython>=4.0.0->ipywidgets<8,>=7) (0.17.2)
# Requirement already satisfied: jupyter-core in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets<8,>=7) (3.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (6.4.6)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<8,>=7) (0.7.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7) (21.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7) (0.18.0)
# Requirement already satisfied: six>=1.11.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets<8,>=7) (1.16.0)
# Requirement already satisfied: entrypoints in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7) (0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7) (1.5.1)
# Requirement already satisfied: pyzmq>=13 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets<8,>=7) (2.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (0.12.1)
# Requirement already satisfied: prometheus-client in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (0.12.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (1.8.0)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (3.0.3)
# Requirement already satisfied: nbconvert in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (6.3.0)
# Requirement already satisfied: argon2-cffi in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (21.1.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets<8,>=7) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets<8,>=7) (0.2.5)
# Requirement already satisfied: cffi>=1.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (1.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (2.0.1)
# Requirement already satisfied: bleach in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (0.8.4)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (0.5.9)
# Requirement already satisfied: testpath in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (0.5.0)
# Requirement already satisfied: defusedxml in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (1.5.0)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (2.21)
# Requirement already satisfied: webencodings in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (0.5.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7) (3.0.6)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: huggingface-hub in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (0.9.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub) (3.4.0)
# Requirement already satisfied: packaging>=20.9 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub) (4.0.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub) (2.26.0)
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub) (4.62.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from huggingface-hub) (5.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from packaging>=20.9->huggingface-hub) (3.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->huggingface-hub) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->huggingface-hub) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->huggingface-hub) (3.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from requests->huggingface-hub) (2.0.7)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (1.10.0)
# Requirement already satisfied: typing_extensions in /home/ec2-user/anaconda3/envs/pytorch_p38/lib/python3.8/site-packages (from torch) (4.0.0)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.
# Package                            Version
# ---------------------------------- --------------
# aiobotocore                        2.0.1
# aiohttp                            3.8.1
# aioitertools                       0.8.0
# aiosignal                          1.2.0
# alabaster                          0.7.12
# anaconda-client                    1.8.0
# anaconda-project                   0.10.2
# anyio                              3.4.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        21.1.0
# arrow                              1.2.1
# asn1crypto                         1.4.0
# astroid                            2.8.6
# astropy                            5.0
# async-generator                    1.10
# async-timeout                      4.0.1
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.6
# autovizwidget                      0.19.1
# awscli                             1.25.42
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# bcrypt                             3.2.2
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.4
# bkcharts                           0.2
# black                              21.11b0
# bleach                             4.1.0
# blis                               0.7.6
# bokeh                              2.4.2
# boto                               2.49.0
# boto3                              1.24.42
# botocore                           1.24.19
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# captum                             0.4.1
# catalogue                          2.0.6
# certifi                            2021.10.8
# cffi                               1.15.0
# chardet                            4.0.0
# charset-normalizer                 2.0.7
# click                              8.0.3
# cloudpickle                        2.0.0
# clyent                             1.2.2
# colorama                           0.4.3
# conda-pack                         0.6.0
# contextlib2                        21.6.0
# cookiecutter                       1.7.0
# coverage                           6.3.2
# cryptography                       36.0.0
# cycler                             0.11.0
# cymem                              2.0.6
# Cython                             0.29.24
# cytoolz                            0.11.2
# dask                               2021.11.2
# debugpy                            1.5.1
# decorator                          5.1.0
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# diffusers                          0.2.4
# dill                               0.3.4
# distributed                        2021.11.2
# distro                             1.7.0
# docker                             5.0.3
# docker-compose                     1.29.2
# dockerpty                          0.4.1
# docopt                             0.6.2
# docutils                           0.15.2
# dparse                             0.5.1
# entrypoints                        0.3
# environment-kernels                1.1.1
# et-xmlfile                         1.0.1
# fastai                             2.1.10
# fastcache                          1.1.0
# fastcore                           1.3.29
# fastprogress                       1.0.2
# filelock                           3.4.0
# flake8                             3.8.4
# Flask                              2.0.2
# Flask-Cors                         3.0.10
# fonttools                          4.28.2
# frozenlist                         1.2.0
# fsspec                             2021.11.1
# ftfy                               6.1.1
# future                             0.18.2
# gevent                             21.8.0
# glob2                              0.7
# gmpy2                              2.1.0rc1
# google-pasta                       0.2.0
# greenlet                           1.1.2
# gssapi                             1.7.3
# h5py                               3.4.0
# hdijupyterutils                    0.19.1
# HeapDict                           1.0.1
# horovod                            0.23.0
# html5lib                           1.1
# huggingface-hub                    0.9.0
# idna                               3.1
# imagecodecs                        2021.11.20
# imageio                            2.9.0
# imagesize                          1.3.0
# importlib-metadata                 4.8.2
# importlib-resources                5.4.0
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.0.2
# ipykernel                          6.5.0
# ipyparallel                        8.0.0
# ipython                            7.32.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isort                              5.10.1
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.17.2
# jeepney                            0.7.1
# Jinja2                             3.0.3
# jinja2-time                        0.2.0
# jmespath                           0.10.0
# joblib                             1.1.0
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     7.1.0
# jupyter-console                    6.4.0
# jupyter-core                       4.9.1
# jupyter-server                     1.12.0
# jupyterlab                         3.2.4
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 1.0.2
# keyring                            23.2.1
# kiwisolver                         1.3.2
# krb5                               0.3.0
# langcodes                          3.3.0
# lazy-object-proxy                  1.6.0
# libarchive-c                       3.1
# llvmlite                           0.36.0
# locket                             0.2.0
# lxml                               4.8.0
# MarkupSafe                         2.0.1
# matplotlib                         3.5.0
# matplotlib-inline                  0.1.3
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.12.0
# mpi4py                             3.0.3
# mpmath                             1.2.1
# msgpack                            1.0.3
# multidict                          5.2.0
# multipledispatch                   0.6.0
# multiprocess                       0.70.12.2
# munkres                            1.1.4
# murmurhash                         1.0.6
# mypy-extensions                    0.4.3
# nb-conda                           2.2.1
# nb-conda-kernels                   2.3.1
# nbclassic                          0.3.4
# nbclient                           0.5.9
# nbconvert                          6.3.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.3
# nltk                               3.6.5
# nose                               1.3.7
# notebook                           6.4.6
# numba                              0.53.1
# numexpr                            2.7.3
# numpy                              1.21.2
# numpydoc                           1.1.0
# olefile                            0.46
# onnx                               1.10.2
# opencv-python                      4.5.1.48
# openpyxl                           3.0.9
# packaging                          21.3
# pandas                             1.3.4
# pandocfilters                      1.5.0
# paramiko                           2.11.0
# parso                              0.7.0
# partd                              1.2.0
# path                               16.2.0
# pathlib2                           2.3.6
# pathos                             0.2.8
# pathspec                           0.9.0
# pathtools                          0.1.2
# pathy                              0.6.1
# patsy                              0.5.2
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             9.0.1
# pip                                22.0.4
# pkginfo                            1.8.1
# platformdirs                       2.3.0
# plotly                             5.6.0
# pluggy                             1.0.0
# ply                                3.11
# pooch                              1.5.2
# pox                                0.3.0
# poyo                               0.5.0
# ppft                               1.6.6.4
# preshed                            3.0.6
# prometheus-client                  0.12.0
# prompt-toolkit                     3.0.22
# protobuf                           3.19.4
# protobuf3-to-dict                  0.1.5
# psutil                             5.8.0
# psycopg2                           2.9.2
# ptyprocess                         0.7.0
# py                                 1.11.0
# py4j                               0.10.9
# pyarrow                            7.0.0
# pyasn1                             0.4.8
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.21
# pycurl                             7.44.1
# pydantic                           1.8.2
# pydocstyle                         6.1.1
# pyerfa                             2.0.0.1
# pyflakes                           2.2.0
# pyfunctional                       1.4.3
# pygal                              2.4.0
# Pygments                           2.10.0
# pyinstrument                       3.4.2
# pyinstrument-cext                  0.2.4
# pykerberos                         1.2.1
# pylint                             2.11.1
# pyls-black                         0.4.6
# pyls-spyder                        0.3.2
# PyNaCl                             1.5.0
# pynvml                             8.0.4
# pyodbc                             4.0.32
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.6
# PyQt5                              5.12.3
# PyQt5_sip                          4.19.18
# PyQtChart                          5.12
# PyQtWebEngine                      5.12.1
# pyrsistent                         0.18.0
# PySocks                            1.7.1
# pyspark                            3.0.0
# pyspnego                           0.5.0
# pytest                             6.2.5
# python-dateutil                    2.8.2
# python-dotenv                      0.20.0
# python-jsonrpc-server              0.4.0
# python-language-server             0.36.2
# pytz                               2021.3
# PyWavelets                         1.2.0
# pyxdg                              0.27
# PyYAML                             5.4.1
# pyzmq                              22.3.0
# QDarkStyle                         3.0.2
# qstylizer                          0.2.1
# QtAwesome                          1.1.0
# qtconsole                          5.2.1
# QtPy                               1.11.2
# regex                              2021.11.10
# requests                           2.26.0
# requests-kerberos                  0.14.0
# rope                               0.22.0
# rsa                                4.7.2
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.80
# s3fs                               0.4.0
# s3transfer                         0.6.0
# safety                             1.10.3
# sagemaker                          2.101.1
# sagemaker-pyspark                  1.4.2
# scikit-image                       0.18.3
# scikit-learn                       1.0.1
# scipy                              1.7.2
# seaborn                            0.11.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.0
# setuptools                         59.2.0
# shap                               0.40.0
# simplegeneric                      0.8.1
# singledispatch                     0.0.0
# sip                                4.19.25
# six                                1.16.0
# sklearn                            0.0
# slicer                             0.0.7
# smart-open                         5.2.1
# smclarify                          0.2
# smdebug                            1.0.12
# smdebug-rulesconfig                1.0.1
# sniffio                            1.2.0
# snowballstemmer                    2.2.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.3
# spacy                              3.2.3
# spacy-legacy                       3.0.9
# spacy-loggers                      1.0.1
# sparkmagic                         0.15.0
# Sphinx                             4.3.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.0.5
# spyder-kernels                     2.0.5
# SQLAlchemy                         1.4.27
# srsly                              2.4.2
# statsmodels                        0.13.1
# sympy                              1.9
# tables                             3.6.1
# tabulate                           0.8.9
# tblib                              1.7.0
# tenacity                           8.0.1
# terminado                          0.12.1
# testpath                           0.5.0
# textdistance                       4.2.2
# texttable                          1.6.4
# thinc                              8.0.15
# threadpoolctl                      3.0.0
# three-merge                        0.1.1
# tifffile                           2021.11.2
# tinycss2                           1.1.1
# tokenizers                         0.12.1
# toml                               0.10.2
# tomli                              1.2.2
# toolz                              0.11.2
# torch                              1.10.0
# torch-model-archiver               0.5.0b20211117
# torch-workflow-archiver            0.2.0b20211118
# torchaudio                         0.10.0
# torchserve                         0.5.0b20211117
# torchtext                          0.11.0
# torchvision                        0.11.1
# tornado                            6.1
# tqdm                               4.62.3
# traitlets                          5.1.1
# transformers                       4.21.1
# typed-ast                          1.5.0
# typer                              0.4.0
# typing_extensions                  4.0.0
# ujson                              4.2.0
# unicodecsv                         0.14.1
# unicodedata2                       13.0.0.post2
# urllib3                            1.26.8
# wasabi                             0.9.0
# watchdog                           2.1.6
# wcwidth                            0.2.5
# webencodings                       0.5.1
# websocket-client                   0.59.0
# Werkzeug                           2.0.3
# wheel                              0.37.0
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.2
# wrapt                              1.13.3
# wurlitzer                          3.0.2
# xlrd                               2.0.1
# XlsxWriter                         3.0.2
# xlwt                               1.3.0
# yapf                               0.31.0
# yarl                               1.7.2
# zict                               2.0.0
# zipp                               3.6.0
# zope.event                         4.5.0
# zope.interface                     5.4.0
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/pytorch_p38/bin/python -m pip install --upgrade pip' command.

# %%
from huggingface_hub import notebook_login
from diffusers import StableDiffusionPipeline
import torch
from torch import autocast

# %%
notebook_login()

# %%
# make sure you're logged in with `huggingface-cli login`
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", revision="fp16", torch_dtype=torch.float16, use_auth_token=True)  
pipe = pipe.to("cuda")

# %%
prompt = "a photograph of an astronaut riding a horse"
with autocast("cuda"):
  image = pipe(prompt)["sample"][0]  # image here is in [PIL format](https://pillow.readthedocs.io/en/stable/)

# Now to display an image you can do either save it such as:
image.save(f"astronaut_rides_horse.png")

# or if you're in a google colab you can directly display it with 
image
